# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import mean_squared_error as mse

# %%
errors = []

######
look_back = 15
######
data = pd.read_csv('Rawfeedable(new)(verion-2)(lb-' + str(4) + '.csv')
xx = [i for i in range(1,97+1)]
for i in range(29,40):
    pred = pd.read_csv(str(i)+".csv" , header=None)
    t = data[data["pat_no"]==i]
    t = t["expected_glucose"]
    plt.plot(xx,pred , color='black')
    plt.plot(xx,t)
    plt.show()
    errors.append((mse(t,pred))**(1/2))
